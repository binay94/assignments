# %%
#Q1. Create your own class to perform a list search operation.
import logging
logging.basicConfig(filename='Q1.log', level=logging.DEBUG , filemode='w', format="%(asctime)s %(levelname)s %(message)s")

class lst_search:
    def search(self):
        logging.info("This is a start of search operation")
        try:
            logging.info("i am inside try block of search method")
            lst=[v for v in input("enter elements to list :").split(',')]
            se=input("Enter item to be searched: ")
            for i in lst:
                if i==se:
                    print(f"{se} Found at {lst.index(se)+1} position")
                    logging.info("I am able to search the item")
                    break
            else:
                print(f"{se} Not Found")        
        except exception as e:
            logging.error("there is some issue with the search operation")
            logging.error(e)
            
c=lst_search()
c.search()
# Out:
# enter elements to list : 12,22,33,44,45
# Enter item to be searched:  45
# 45 Found at 5 position

# %%
#Q2. Create a class for dict new element addition.
import logging
logging.basicConfig(filename='Q2.log', level=logging.DEBUG , filemode='w', format="%(asctime)s %(levelname)s %(message)s")

class add_ele:
    def __init__(self,a):
        self.a=a
    def add(self,ae):
        logging.info("This is a start of add operation")
        try:
            logging.info("i am inside try block of add method")
            if type(ae)==dict :
                self.a.update(ae)
                logging.info("I am able to add the item")
                print(self.a)
            else:
                print(f"{ae} is not a dict element")
        except Exception as e:
            logging.error("there is some issue with the add operation")
            logging.error(e)
j=add_ele({'a':1,'b':2})
j.add({'c':3})
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
#Q3. Create a class for tuple data extraction operation.
import logging
logging.basicConfig(filename='Q3.data', level=logging.DEBUG , filemode='w', format="%(asctime)s %(levelname)s %(message)s")
class tup_ext:
    def __init__(self,t):
        self.t=t
        print("entered tuple: ",t)
    def tup_opn(self,si,ei):
        self.si=si
        self.ei=ei
        try:
            logging.info("This is a start of tuple extraction" )
            if(self.ei<=len(self.t)):
                print(f"extracted element of tuple : {self.t[si:ei]}")
            else:
                print("invalid index input")
        except Exception as e:
            logging.error("there is some error in tuple extraction")
            logging.error(e)
           
t=tup_ext((11,12,13,14,15,16,'abc',45,46))
t.tup_opn(0,6)
t.tup_opn(6,9)
t.tup_opn(6,10)
# Out:
# entered tuple:  (11, 12, 13, 14, 15, 16, 'abc', 45, 46)
# extracted element of tuple : (11, 12, 13, 14, 15, 16)
# extracted element of tuple : ('abc', 45, 46)
# invalid index input

# %%
#Q4.  Create a class to implement all insert , update , delete operation for mysql.
import mysql.connector
class mysql_opn:
    def __init__(self,host,user,password):
        self.host=host
        self.user=user
        self.password=password
    def sql_con(self):
        self.mydb=mysql.connector.connect(host=self.host,user=self.user,password=self.password)
        return self.mydb
    def sql_cursor(self):
        self.cursor=self.mydb.cursor()
        return self.cursor
    def database(self,db_name):
        try:
            self.db_name=db_name
            self.cursor.execute(f'create database if not exists {self.db_name}')
        except Exception as e:
            print(e)
    def table(self,sqldata):
        try:
            self.sqldata=sqldata
            self.cursor.execute(f'use {self.db_name}')
            self.cursor.execute(f'create table if not exists {self.sqldata}')
        except Exception as e:
            print(e)
    
    def insert(self,idata):
        try:
            self.idata=idata
            self.cursor.execute(f'use {self.db_name}')
            self.cursor.execute(self.idata)
            self.mydb.commit()
        except Exception as e:
            print(e)
            
    def update(self,udata):
        try:
            self.udata=udata
            self.cursor.execute(self.udata)
            self.mydb.commit()
        except Exception as e:
            print(e)
    
    def getdetails(self,detail):
        self.detail=detail
        self.cursor.execute(self.detail)
        #print(self.cursor.fetchall())
        
    def delete(self,ddata):
        try:
            self.ddata=ddata
            self.cursor.execute(self.ddata)
            self.mydb.commit()
        except Exception as e:
            print(e)
db1=mysql_opn("localhost","abc","password")     
db1.sql_con()
db1.sql_cursor()   
db1.database("assn1501") 
db1.table("table1(roll_no int(5),name varchar(20),address varchar(30),contact_no int(101))")   
#db1.insert('insert into table1 values(38,"goura","anupam bharat padisha",98614),(42,"jiten","khajuria road",79780)')
#db1.getdetails("select * from assn1501.table1")
#db1.update("update assn1501.table1 set address='danger area' where address='khajuria road'")
#db1.getdetails("select * from assn1501.table1")
db1.delete("delete from assn1501.table1 where name='jiten'")

# %%
#q5 : create a class to implement insert , update and delete in monngo db
import pymongo,logging
logging.basicConfig(filename='Q3.data', level=logging.DEBUG , filemode='w', format="%(asctime)s %(levelname)s %(message)s")
class mongo_opn:
    def __init__(self):
        logging.info('connecting to mongo db')
        client=pymongo.MongoClient("mongodb+srv://bkpineuron:bkpineuron@cluster0.rm9j6nc.mongodb.net/?retryWrites=true&w=majority")
        db=client.test
        logging.info('connection to mongo db done')
        database=client['task1501']
        logging.info('database created')
        self.coll=database['user']
        logging.info('collection created')
        
        
    def insert_data(self):
        try:
            logging.info('inserting data in to collection')
            rollno=int(input("enter roll number :"))
            fname=input("enter first name :")
            lname=input("enter last name :")
            sub=input("enter subject :")
            cno=int(input("enter contact number :"))
            data={'rollno':rollno,'first_name':fname,'last_name':lname,'subject':sub,'contact_no':cno}
            logging.info('data inserted to collection')
            self.coll.insert_one(data)
            print("data inserted successfully")
        except pymongo.errors.OperationFailure as e :
            logging.error('there is some error')
            print(f'some error occurred : {e}')
    def get_alldata(self):
        try:
            logging.info('getting data from collection')
            data=self.coll.find()
            print("***** DATA *****")
            for i in data:
                print(i,sep=',')
            logging.info('data from collection displayed')
        except pymongo.errors.Operationfailure as e:
            logging.error('there is some error')
            print(f'some error occurred: {e}')
                  
    def get_spdata(self) :
        try:
            logging.info('getting specific data from collection')
            rno=int(input("enter roll no to find:"))
            data=self.coll.find({'rollno':rno})
            print("***** DATA *****")
            for i in data:
                print(i,sep=',')
            logging.info("specific data from collection displayed")
        except pymongo.errors.Operationfailure as e:
            logging.error('there is some error')
            print(f'some error occurred: {e}')  
     
    def update(self):
        try:
            logging.info('updating data started')
            rno=int(input("enter rollno for updation:"))
            data=self.coll.find({'rollno':rno})
            if data:
                print(f"***** Data Found for {data} *****")
                for i in data:
                    print(i)
                fn=input("enter updated first name :")
                ln=input("enter updated last name :")
                sb=input("enter updated subject :")
                cn=int(input("enter updated contact :"))
                self.coll.update_one({'rollno':rno},{"$set":{'first_name':fn,'last_name':ln,'subject':sb,'contact_no':cn}})
                print("data updated successfully")
                logging.info("data updated successfully")
            
        except pymongo.errors.Operationfailure as e:
            logging.error('there is some error')
            print(f'some error occurred: {e}')
            
    def del_spdata(self):
        try:
            logging.info("data deletion started")
            rno=int(input("enter rollno for deletion:"))
            data=self.coll.find({'rollno':rno})
            print(data)
            if data:
                print(f"***** Data Found for {data} *****")
                for i in data:
                    print(i)
                print('Are you sure want to delete data(yes/no) :')
                ch=input("enter (yes/no) :")
                if ch.lower()=="yes":
                    self.coll.delete_one({'rollno':rno})
                    logging.info('data deleted successfully')
                    print('Data deleted Successfully')
                else:
                    print('cancelled for data deletion')
        except pymongo.errors.Operationfailure as e:
            logging.error('there is some error')
            print(f'some error occurred: {e}')

obj=mongo_opn()
print("Choose ur operation to be performed:")
print("1.insertion of data")
print("2.get all data")
print("3.get specific data")
print("4.update data")
print("5.delete data")
ch=int(input("enter ur choice of operation:"))
if 0<ch<=5:
    if ch==1:
        obj.insert_data()
    if ch==2:
        obj.get_alldata()
    if ch==3:
        obj.get_spdata()
    if ch==4:
        obj.update()
    if ch==5:
        obj.del_spdata()
else:
    print("invalid input:enter choice from 1 to 5 only")

# %%
#q6 : create a class to perform append and delete operation in a file and inherit it in child class 
import pymongo,logging
logging.basicConfig(filename='Q3.data', level=logging.DEBUG , filemode='w', format="%(asctime)s %(levelname)s %(message)s")
class parent:
    def __init__(self,fname):
        self.fname=fname
    def read(self):
        try:
            logging.info("start of reading of file")
            with open(self.fname,'r')as fp:
                data=fp.read()
                logging.info('file readed')
                print("data from file :",data)
        except Exception as e:
            logging.error('there is some error in opening the file') 
            logging.error(e)
    def write(self,txt):
        try:
            logging.info("start of writting to file")
            with open(self.fname,'a')as fp:
                fp.write(txt)
                logging.info('data appended to file')
        except Exception as e:
            logging.error('there is some error in writtong to the file') 
            logging.error(e)
class child(parent):
    def__init__(self,fname):
        parent.__init__(self,fname)

# %%
#q7 : create a class to import a data into file from mongo db
import pymongo
class impmdb:
    def __init__(self,clurl,fname):
        self.clurl=clurl
        self.fname=fname
        self.client=pymongo.MongoClient(self.clurl)
        self.db=self.client.test
    def crcol(self,dbname,colname):
        self.database=self.client[dbname]
        self.coll=self.database[colname]
    def importing_record(self):
        record = []
        for i in self.coll.find():
            record.append(i)
        with open(self.fname, 'w') as f:
            f.write(str(record))
    def show_data(self):
        with open(self.fname,'r')as fp:
            data=fp.read()
            #for i in data:
        print(data)
obj=impmdb("mongodb+srv://bkpineuron:bkpineuron@cluster0.rm9j6nc.mongodb.net/?retryWrites=true&w=majority",'test1.data')
obj.crcol('ineuron','test1')
obj.importing_record()
obj.show_data()

# %%
#q8 : Create a class to build a calculator funcnalities addition , subtraction , multiplication ,div , log , exponenet , power 
import math,logging
logging.basicConfig(filename='Q8.data', level=logging.DEBUG , filemode='w', format="%(asctime)s %(levelname)s %(message)s")
class Calculator():
    def input_values(self):
        logging.info("This is a start of input values")
        try:
            self.a=float(input("enter 1st number:"))
            self.b=float(input("enter 2nd number:"))
            self.op=input("enter an operation from the list mentioned below :\n sum \n substraction \n multiplication \n division \n exponentiation \n log \n")
            logging.info("This is a end of input values")
        except ValueError as v:
            logging.error("invalid input")
            logging.error(e)
    def operation(self):
        logging.info("This is a start of Math Operation")
        try:
            if self.op.lower()=='sum':
                print(f"Sum({self.a}+{self.b})={self.a+self.b}")
            elif self.op.lower()=='substraction':
                print(f"Substraction({self.a},{self.b})={self.a-self.b}")
            elif self.op.lower()=='multiplication':
                print(f"Multiplication({self.a},{self.b})={self.a*self.b}")
            elif self.op.lower()=='division':
                print(f"Division({self.a},{self.b})={self.a/self.b}")
            elif self.op.lower()=='exponentiation':
                print(f"Exponentiation({self.a},{self.b})={self.a**self.b}")
            elif self.op.lower()=='log':
                print(f"Logarithm({self.a},{self.b})={math.log(self.a,self.b)}")
            else :
                print("invalid operator input")
            logging.info("This is a end of Math Operation")
        except Exception as v:
            logging.error("there is some issue with the Math operation")
            logging.error(e)
            
c=Calculator()
c.input_values()
c.operation()

# %%
#q9 : create a class method to find a time and space complexity of any function
import time,tracemalloc
class complexity:
    def time_complexity(self,fn,*args):
        start_time=time.time()
        fn(*args)
        end_time=time.time()
        return end_time-start_time
    def space_complexity(self,fn,*args):
        tracemelloc.start()
        fn(*args)
        current,peak=tracemelloc.get_traced_memory()
        tracemelloc.stop()
        return current,peak

# %%
#q10: create a class to do a bulk uplaod of a file in mysql 
import mysql.connector
def busql:
    def __init__(self,host,user,password,dbname):
        self.host=host
        self.user=user
        self.password=password
        self.mydb=mysql.connector.connect(host=self.host,user=self.user,password=self.password)
        self.cur=self.mydb.cursor()
        self.dbname=dbname
        self.cur.execute(f'create database {self.dbname}')
    def create_table(self,tabname,columns):
        self.tabname=tabname
        self.columns=columns
        self.cur.execute(f'create table if not exists {self.tabname}({self.columns})')
        self.mydb.commit()
    def insert_file(self,csv_file):
        with open(csv_file,'r')as fp:
            data=csv.reader(fp,delimeter='\n')
            next(data)
            for i in data:
                self.cur.execute(f"insert into {self.dbname}.{self.mydb} values({str(i[0])})")
        self.mydb.commit()
    def show_data():
        self.cur.execute(f'select * from {self.dbname}.{self.tabname}')
        print(self.cursor.fetchall())
o=busql(host,abc,password)
o.create_table(table1,)
